# %% [markdown]
# # Two Integer Sum II

# %% [markdown]
# - https://neetcode.io/problems/two-integer-sum-ii/question?list=neetcode150

# %% [markdown]
# ### Given an array of integers numbers that is sorted in non-decreasing order.
#
# ### Return the indices (1-indexed) of two numbers, [index1, index2], such that they add up to a given target number target and index1 < index2.
#
# ### Note that index1 and index2 cannot be equal, therefore you may not use the same element twice.
#
# There will always be exactly one valid solution.
#
# Your solution must use O(1) additional space.
#
# ### Example 1:
#
# Input: numbers = [1,2,3,4], target = 3
#
# Output: [1,2]
# Explanation:
# The sum of 1 and 2 is 3. Since we are assuming a 1-indexed array, index1 = 1, index2 = 2. We return [1, 2].
#
# Constraints:
#
# - 2 <= numbers.length <= 1000
# - -1000 <= numbers[i] <= 1000
# - -1000 <= target <= 1000

# %% [markdown]
# - https://chatgpt.com/share/69df4579-edf4-83e8-be18-0dfe543e410f

# %% [markdown]
# 🔴 What’s actually wrong
#
# Your hashmap solution:
#
# seen[num] = index + 1
#
# This fails because of duplicates + sorted constraint + expected smallest index pair.
#
# In this test case:
#
# Your code finds a valid pair → [748, 749]
# But the problem expects the leftmost valid pair → [498, 999]
#
# 👉 LeetCode requires the correct pair based on sorted order, not just any valid pair.
#
# - so multiple solutions, but we need to return as per the sorted order and smallest indices.

# %% [markdown]
# ### Solution

# %%
from typing import List



class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        left,right=0,len(numbers)-1
        while left<right: # the condition doesnt matter because we are guaranteed a solution
            curSum=numbers[left]+numbers[right]

            if curSum>target:
                right-=1
            elif curSum<target:
                left+=1
            else:
                return [left+1,right+1]
        return []

# %% [markdown]
# ### approach
#     - two pointers, left and right
#     - if sum is greater than target, move right pointer left
#     - if sum is less than target, move left pointer right
#     - if sum equals target, return the indices
#
# - steps
#     - set left, right pointers
#     - while left < right:
#         - calculate current sum
#         - if current sum is greater than target, move right pointer left
#         - if current sum is less than target, move left pointer right
#         - if current sum equals target, return the indices
#     - return empty list if no solution found (though problem guarantees a solution)
