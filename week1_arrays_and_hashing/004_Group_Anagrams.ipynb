# %% [markdown]
# # 004. Group Anagrams

# %% [markdown]
# https://neetcode.io/problems/anagram-groups/question?list=neetcode150

# %% [markdown]
# ### Given an array of strings strs, group all anagrams together into sublists. You may return the output in any order.
#
# ### An anagram is a string that contains the exact same characters as another string, but the order of the characters can be different.
#
# ### Example 1:
#
# Input: strs = ["act","pots","tops","cat","stop","hat"]
#
# Output: [["hat"],["act", "cat"],["stop", "pots", "tops"]]
# ### Example 2:
#
# Input: strs = ["x"]
#
# Output: [["x"]]
# ### Example 3:
#
# Input: strs = [""]
#
# Output: [[""]]
# ### Constraints:
#
# - 1 <= strs.length <= 1000.
# - 0 <= strs[i].length <= 100
# - strs[i] is made up of lowercase English letters.

# %% [markdown]
# # Solution

# %%
from typing import List
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        data={}
        for ana in strs:
            if tuple(sorted(ana)) not in data:
                data[tuple(sorted(ana))]=[ana]
            else:
                data[tuple(sorted(ana))].append(ana)
        return list(data.values())

# %% [markdown]
# # Approach 1:

# %% [markdown]
#     - create a data dict
#     - iterate through the strs and `if tuple(sorted(i)) not in data` then add the sorted tuple as key and the string as value in a list `else` append the string to the list of the sorted tuple key
#     - return the values of the dict
#
#     ### why sorted tuple as key?
#     - because anagrams will have the same characters and the same frequency of characters so when we sort the string the anagrams will have the same sorted tuple as key
