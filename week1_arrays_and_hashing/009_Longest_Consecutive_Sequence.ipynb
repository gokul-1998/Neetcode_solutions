# %% [markdown]
# # Longest Consecutive Sequence

# %% [markdown]
# - https://neetcode.io/problems/longest-consecutive-sequence/question?list=neetcode150

# %% [markdown]
# ### Given an array of integers nums, return the length of the longest consecutive sequence of elements that can be formed.
#
# A consecutive sequence is a sequence of elements in which each element is exactly 1 greater than the previous element. The elements do not have to be consecutive in the original array.
#
# You must write an algorithm that runs in O(n) time.
#
# ### Example 1:
#
# Input: nums = [2,20,4,10,3,4,5]
#
# Output: 4
#
# Explanation: The longest consecutive sequence is [2, 3, 4, 5].
#
# Example 2:
#
# Input: nums = [0,3,2,5,4,6,1,1]
#
# Output: 7
#
# ### Constraints:
#
# - 0 <= nums.length <= 1000
# - -10^9 <= nums[i] <= 10^9

# %% [markdown]
# ### Solution

# %%
from typing import List
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        numSet=set(nums)
        longest=0

        for n in nums:
            # check if its the start of a sequence

            if (n-1) not in numSet:
                length=0
                while (n+length) in numSet:
                    length+=1
                longest=max(length,longest)
        return longest

# %% [markdown]
# ### Approach
#     - convert the list to a set for O(1) lookups
#     - longest=0
#     - iterate over all the nums,
#         - check if the current numbers previous number does not exist in the set, if it does not exist, it is a start of a sequence, and using while loop, get the length of the sequence,
#         - after the loop, find the max of current length, and the longest and assign to the longest
#     - return longest.
